# %%
# %reload_ext tensorboard
import datetime

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

import tensorflow.keras.layers as layers
import tensorflow.keras.models as models
import tensorflow.keras.losses as losses
import tensorflow.keras.optimizers as optimizers

import tensorflow_datasets as tfds

from tensorflow.data import AUTOTUNE

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    tf.config.experimental.set_virtual_device_configuration(gpus[0], [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024)])
  except RuntimeError as e:
    print(e)
#if gpus:
#  try:
#    for gpu in gpus:
#      tf.config.experimental.set_memory_growth(gpu, True)
#  except RuntimeError as e:
#    print(e)
# Out:
# Found GPU at: /device:GPU:0

# %%
import tensorflow as tf

import tensorflow.keras.layers as layers
import tensorflow.keras.losses as losses
import tensorflow.keras.metrics as metrics
import tensorflow.keras.models as models
import tensorflow.keras.optimizers as optimizers


# default input shape
INPUT_SHAPE = (512, 1024, 3)


def ge_layer(x_in, c, e=6, stride=1):
    x = layers.Conv2D(filters=c, kernel_size=(3,3), padding='same')(x_in)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    if stride == 2:
        x = layers.DepthwiseConv2D(depth_multiplier=e, kernel_size=(3,3), strides=2, padding='same')(x)
        x = layers.BatchNormalization()(x)
        
        y = layers.DepthwiseConv2D(depth_multiplier=e, kernel_size=(3,3), strides=2, padding='same')(x_in)
        y = layers.BatchNormalization()(y)
        y = layers.Conv2D(filters=c, kernel_size=(1,1), padding='same')(y)
        y = layers.BatchNormalization()(y)
    else:
        y = x_in
        
    x = layers.DepthwiseConv2D(depth_multiplier=e, kernel_size=(3,3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(filters=c, kernel_size=(1,1), padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    x = layers.Add()([x, y])
    x = layers.Activation('relu')(x)
    return x


def stem(x_in, c):
    x = layers.Conv2D(filters=c, kernel_size=(3,3), strides=2, padding='same')(x_in)
    x = layers.BatchNormalization()(x)
    x_split = layers.Activation('relu')(x)
    
    x = layers.Conv2D(filters=c // 2, kernel_size=(1,1), padding='same')(x_split)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    x = layers.Conv2D(filters=c, kernel_size=(3,3), strides=2, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    y = layers.MaxPooling2D()(x_split)
    
    x = layers.Concatenate()([x, y])
    x = layers.Conv2D(filters=c, kernel_size=(3,3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    return x


def detail_conv2d(x_in, c, stride=1):
    x = layers.Conv2D(filters=c, kernel_size=(3,3), strides=stride, padding='same')(x_in)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    return x


def context_embedding(x_in, c):
    x = layers.GlobalAveragePooling2D()(x_in)
    x = layers.BatchNormalization()(x)
    
    x = layers.Reshape((1,1,c))(x)
    
    x = layers.Conv2D(filters=c, kernel_size=(1,1), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    # broadcasting no needed
    
    x = layers.Add()([x, x_in])
    x = layers.Conv2D(filters=c, kernel_size=(3,3), padding='same')(x)
    return x


def bilateral_guided_aggregation(detail, semantic, c):
    # detail branch
    detail_a = layers.DepthwiseConv2D(kernel_size=(3,3), padding='same')(detail)
    detail_a = layers.BatchNormalization()(detail_a)
    
    detail_a = layers.Conv2D(filters=c, kernel_size=(1,1), padding='same')(detail_a)
    
    detail_b = layers.Conv2D(filters=c, kernel_size=(3,3), strides=2, padding='same')(detail)
    detail_b = layers.BatchNormalization()(detail_b)
    
    detail_b = layers.AveragePooling2D((3,3), strides=2, padding='same')(detail_b)
    
    # semantic branch
    semantic_a = layers.DepthwiseConv2D(kernel_size=(3,3), padding='same')(semantic)
    semantic_a = layers.BatchNormalization()(semantic_a)
    
    semantic_a = layers.Conv2D(filters=c, kernel_size=(1,1), padding='same')(semantic_a)
    semantic_a = layers.Activation('sigmoid')(semantic_a)
    
    semantic_b = layers.Conv2D(filters=c, kernel_size=(3,3), padding='same')(semantic)
    semantic_b = layers.BatchNormalization()(semantic_b)
    
    semantic_b = layers.UpSampling2D((4,4), interpolation='bilinear')(semantic_b)
    semantic_b = layers.Activation('sigmoid')(semantic_b)
    
    # combining
    detail = layers.Multiply()([detail_a, semantic_b])
    semantic = layers.Multiply()([semantic_a, detail_b])
    
    # this layer is not mentioned in the paper !?
    #semantic = layers.UpSampling2D((4,4))(semantic)
    semantic = layers.UpSampling2D((4,4), interpolation='bilinear')(semantic)
    
    x = layers.Add()([detail, semantic])
    x = layers.Conv2D(filters=c, kernel_size=(3,3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    return x


def seg_head(x_in, c_t, s, n):
    x = layers.Conv2D(filters=c_t, kernel_size=(3,3), padding='same')(x_in)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    x = layers.Conv2D(filters=n, kernel_size=(3,3), padding='same')(x)
    x = layers.UpSampling2D((s,s), interpolation='bilinear')(x)
    
    return x


class ArgmaxMeanIOU(metrics.MeanIoU):
    def update_state(self, y_true, y_pred, sample_weight=None):
        return super().update_state(tf.argmax(y_true, axis=-1), tf.argmax(y_pred, axis=-1), sample_weight)


def bisenetv2(num_classes=2, out_scale=8, input_shape=INPUT_SHAPE, l=4, seghead_expand_ratio=2):
    x_in = layers.Input(input_shape)

    # semantic branch
    # S1 + S2
    x = stem(x_in, 64 // l)
    
    # S3
    x = ge_layer(x, 128 // l, stride=2)
    x = ge_layer(x, 128 // l, stride=1)

    # S4
    x = ge_layer(x, 64, stride=2)
    x = ge_layer(x, 64, stride=1)

    # S5
    x = ge_layer(x, 128, stride=2)

    x = ge_layer(x, 128, stride=1)
    x = ge_layer(x, 128, stride=1)
    x = ge_layer(x, 128, stride=1)

    x = context_embedding(x, 128)

    # detail branch
    # S1
    y = detail_conv2d(x_in, 64, stride=2)
    y = detail_conv2d(y, 64, stride=1)

    # S2
    y = detail_conv2d(y, 64, stride=2)
    y = detail_conv2d(y, 64, stride=1)
    y = detail_conv2d(y, 64, stride=1)

    # S3
    y = detail_conv2d(y, 128, stride=2)
    y = detail_conv2d(y, 128, stride=1)
    y = detail_conv2d(y, 128, stride=1)

    x = bilateral_guided_aggregation(y, x, 128)

    x = seg_head(x, num_classes * seghead_expand_ratio, out_scale, num_classes)
    
    model = models.Model(inputs=[x_in], outputs=[x])
    
    # set weight initializers
    for layer in model.layers:
        if hasattr(layer, 'kernel_initializer'):
            layer.kernel_initializer = tf.keras.initializers.HeNormal()
        if hasattr(layer, 'depthwise_initializer'):
            layer.depthwise_initializer = tf.keras.initializers.HeNormal()

    return model


def bisenetv2_compiled(num_classes, decay_steps=10e3, momentum=0.9, weight_decay=0.0005, **kwargs):
    model = bisenetv2(num_classes, **kwargs)

    schedule = optimizers.schedules.PolynomialDecay(
        initial_learning_rate=5e-2,
        decay_steps=decay_steps,
        power=0.9
    )

    try:
        import tensorflow_addons as tfa

        sgd = tfa.optimizers.SGDW(
            weight_decay=weight_decay,
            learning_rate=schedule,
            momentum=momentum,
        )
    except ImportError:
        print('tensorflow_addons not available, not using weight-decay')

        sgd = optimizers.SGD(
            learning_rate=schedule,
            momentum=momentum,
        )

    cce = losses.CategoricalCrossentropy(from_logits=True)

    model.compile(sgd, loss=cce,
                  metrics=['accuracy', ArgmaxMeanIOU(num_classes)]) 
    
    return model


def bisenetv2_output_shape(num_classes, scale, input_shape=INPUT_SHAPE):
    return ((input_shape[0] // 8) * scale, 
            (input_shape[1] // 8) * scale, 
            num_classes)

# %%
import json
import tensorflow as tf
import numpy as np
import cv2


def class_map_road(seg):
    # map class 0=anything, 1=road
    return tf.where(seg == 7, [0, 1.0], [1.0, 0])


def cityscapes_prep(output_shape, input_shape=INPUT_SHAPE, class_map_func=None, float_range=True):
    def prep_map(sample):
        img = sample['image_left']
        seg = sample['segmentation_label']

        if float_range:
            img /= 255

        img = tf.image.resize(img, input_shape[0:2])
        seg = tf.image.resize(seg, output_shape[0:2])
        
        if callable(class_map_func):
            seg = class_map_func(seg)
        else:
            seg = tf.one_hot(tf.cast(seg, tf.int32), output_shape[-1], axis=2)
            seg = tf.cast(seg, tf.float32)
            seg = tf.squeeze(seg)
            #seg = tf.keras.utils.to_categorical(seg, num_classes=output_shape[-1])

        return img, seg

    return prep_map

# %%
import matplotlib.pyplot as plt


def segmentation_to_image(pred):
    img = tf.argmax(pred, axis=-1)
    img = img[..., tf.newaxis]
    return tf.keras.preprocessing.image.array_to_img(img)

        
def predict_tf(model):
    def predict_func(sample):
        print(sample[0])
        pred = model.predict(tf.expand_dims(sample[0], axis=0))
        return sample[0], pred[0]
    
    return predict_func


def display_dataset(ds, pred_func):
    for sample in ds:
        imgs = pred_func(sample)
        fig, axes = plt.subplots(1, len(imgs))
        
        for ax, img in zip(axes, imgs):
            if img.shape[-1] != 3:
                img = segmentation_to_image(img)
                
            ax.imshow(img)

# %%
# Test a image input
import cv2
import time
def img_pred(src,model):
  src = cv2.cvtColor(src, cv2.COLOR_BGR2RGB)
  #cv2_imshow(src)
  src = cv2.resize(src,(512,256),interpolation=cv2.INTER_CUBIC)
  #cv2_imshow(src)
  image = src/255
  data = tf.convert_to_tensor(image, dtype=tf.float32)
  data = tf.expand_dims(data, axis=0)
  pred = model.predict(data)
  seg = tf.argmax(pred[0], axis=-1)
  seg = seg[..., tf.newaxis]
  seg = tf.keras.preprocessing.image.array_to_img(seg)
  #plt.imshow(seg)
  seg = cv2.cvtColor(np.array(seg), cv2.COLOR_BGR2RGB)
  result = cv2.addWeighted(src, 0.6, seg, 0.5, 0, dtype = cv2.CV_8U)
  return src, seg, result

# %%
def gen_seg_vid(cap,out,shape,model):
  while(cap.isOpened()):
    ret, frame = cap.read()
    if ret == True:
      start = time.time()
      img_seg = img_pred(frame,model)[2]
      end = time.time()
      fps = 1/(end - start)
      x = 'FPS:'
      img_seg = cv2.resize(img_seg,(2048,1024),interpolation=cv2.INTER_CUBIC)
      text = "{}{:.3f}".format(x,fps)
      font = cv2.FONT_HERSHEY_SIMPLEX
      #cv2_imshow(img_seg)
      img_seg = cv2.cvtColor(img_seg, cv2.COLOR_BGR2RGB)
      cv2.putText(img_seg, text , (800,900), font, 1, (0, 255, 255), 2, cv2.LINE_AA)
      out.write(img_seg)
      if cv2.waitKey(100) & 0xFF == ord('q'):
        break
    else:
      break
  cap.release()
  out.release()
  cv2.destroyAllWindows()

# %%
INPUT_SHAPE = (256, 512, 3)
NUM_CLASSES = 2
SCALE = 8

# %%
OUTPUT_SHAPE = bisenetv2_output_shape(NUM_CLASSES, SCALE, input_shape=INPUT_SHAPE)
#m = bisenetv2_compiled(num_classes=NUM_CLASSES, out_scale=SCALE, input_shape=INPUT_SHAPE)

# %%
m = tf.keras.models.load_model('E:\EE\project\FPGA\model8.tf',custom_objects={'ArgmaxMeanIOU': ArgmaxMeanIOU})

# %%
m.summary()

# %%
#tf.keras.utils.plot_model(m, show_shapes=True)

# %%
cityscapes = tfds.load('cityscapes/semantic_segmentation',data_dir="E:\EE\project\FPGA\cityscapes",download=False)

# %%
train_ds = cityscapes['train'].map(cityscapes_prep(OUTPUT_SHAPE, INPUT_SHAPE, class_map_road))
valid_ds = cityscapes['validation'].map(cityscapes_prep(OUTPUT_SHAPE, INPUT_SHAPE, class_map_road))
test_ds = cityscapes['test'].map(cityscapes_prep(OUTPUT_SHAPE, INPUT_SHAPE, class_map_road))

# %%
display_dataset(train_ds.take(1), lambda s: (s[0], s[1]))

# %%
BATCH_SIZE = 16

USE_TINYCAR_DATA = False
USE_AUGMENTATION = False

rng = tf.random.Generator.from_seed(123, alg='philox')

if USE_TINYCAR_DATA:
    from data_prep import labelme_prep, uwula_prep

    ds = tf.data.Dataset.list_files('../paperstreet/1/*.json')
    ds = ds.map(labelme_prep(OUTPUT_SHAPE, INPUT_SHAPE))


    ds2 = tf.data.Dataset.list_files('/media/mldata/tinycar/Mikrowunderland_1k/*.jpg')
    ds2 = ds2.map(uwula_prep(OUTPUT_SHAPE, INPUT_SHAPE))

    ds = ds.concatenate(ds2)
    
    tc_valid_ds = ds.take(24)
    tc_train_ds = ds.skip(24)
    
    train_ds = train_ds.concatenate(tc_train_ds)
    valid_ds = train_ds.concatenate(tc_valid_ds)

if USE_AUGMENTATION:
    def augment(img, seg, seed):
        #seed = tf.random.uniform((2,))
        img = tf.image.stateless_random_brightness(img, 0.2, seed=seed)
        img = tf.image.stateless_random_contrast(img, 0.8, 1.2, seed=seed)
        img = tf.image.stateless_random_saturation(img, 0.0, 1.5, seed=seed)
        img = tf.image.stateless_random_hue(img, 0.2, seed=seed)
        img = tf.clip_by_value(img, 0.0, 1.0) # clip values outside 0..1

        return img, seg

    def randomize(img, seg):
        seed = rng.make_seeds(2)[0]
        img, seg = augment(img, seg, seed)
        return img, seg

    train_ds_flipped_lr = train_ds.map(lambda img, seg: (tf.image.flip_left_right(img), tf.image.flip_left_right(seg)))
    valid_ds_flipped_lr = valid_ds.map(lambda img, seg: (tf.image.flip_left_right(img), tf.image.flip_left_right(seg)))
    
    train_ds_randomized = train_ds.map(randomize)
    valid_ds_randomized = valid_ds.map(randomize)
    
    train_ds_randomized_flipped = train_ds_flipped_lr.map(randomize)
    valid_ds_randomized_flipped = valid_ds_flipped_lr.map(randomize)
    
    train_ds = train_ds.concatenate(train_ds_flipped_lr).concatenate(train_ds_randomized).concatenate(train_ds_randomized_flipped)
    valid_ds = valid_ds.concatenate(valid_ds_flipped_lr).concatenate(valid_ds_randomized).concatenate(valid_ds_randomized_flipped)


train_ds = train_ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)
valid_ds = valid_ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)

#display_dataset(valid_ds.unbatch().take(5), lambda s: (s[0], s[1]))

# %%
display_dataset(train_ds_randomized_flipped.take(10), lambda s: (s[0], s[1]))

# %%
EPOCHS = 10

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

history = m.fit(train_ds,
                validation_data=test_ds,
                epochs=EPOCHS,
                callbacks=[tensorboard_callback])

# %%
m.save('/content/drive/MyDrive/model.tf')
#m.save('model_untrained.tf')

# %%
print("Evaluate on valid data")
results = m.evaluate(valid_ds)

# %%
display_dataset(test_ds.unbatch().take(1), predict_tf(m))
#display_dataset(valid_ds.unbatch().take(20), predict_tf(m))

# %%
# Test Image
src = cv2.imread('E:/EE/project/FPGA/test_01.png')
start = time.time()
result = img_pred(src,m)[2]
end = time.time()
fps = 1/(end-start)
print('fps =',fps)
cv2.imshow("result",result)
cv2.waitKey (0)

# %%
cap = cv2.VideoCapture('/content/drive/MyDrive/Colab_Notebooks/FPGA_RoadSeg/Driving_data.mp4')
fourcc = cv2.VideoWriter_fourcc(*'MP4V')
out = cv2.VideoWriter('/content/drive/MyDrive/Colab_Notebooks/FPGA_RoadSeg/Dirve_test.mp4',fourcc,10,(2048,1024))
gen_seg_vid(cap,out,(2048,1024),m)

# %%
import tensorflow_addons as tfa

decay_steps=10e3
momentum=0.9
weight_decay=0.0005

schedule = optimizers.schedules.PolynomialDecay(
        initial_learning_rate=5e-5,
        decay_steps=decay_steps,
        power=0.9
    )
sgd = tfa.optimizers.SGDW(
            weight_decay=weight_decay,
            learning_rate=schedule,
            momentum=momentum,
        )
cce = losses.CategoricalCrossentropy(from_logits=True)

# %%
print(len(train_ds))

# %%
# Prune the original TF model
import tensorflow_model_optimization as tfmot
import tensorflow as tf

model = tf.keras.models.load_model('E:\EE\project\FPGA\model8.tf',custom_objects={'ArgmaxMeanIOU': ArgmaxMeanIOU})

prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude

epochs = 5
end_step = np.ceil(len(train_ds)).astype(np.int32)*epochs
pruning_params = {
      'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.5,
                                    final_sparsity=0.80,
                                    begin_step=0,
                                    end_step=end_step)}
#pruning_params = {
#      'pruning_schedule': tfmot.sparsity.keras.ConstantSparsity(0.5, begin_step=0, frequency=100)
#  }
opt = tf.keras.optimizers.Adam(learning_rate=5e-6)
pruned_model = prune_low_magnitude(model, **pruning_params)

pruned_model.compile(opt, loss=cce,
                  metrics=['accuracy', ArgmaxMeanIOU(NUM_CLASSES)]) 
pruned_model.summary()

# %%
# Fine-tuning on trained tf model

import tempfile

logdir = tempfile.mkdtemp()
callbacks = [
  tfmot.sparsity.keras.UpdatePruningStep()
]   
history = pruned_model.fit(train_ds,
                validation_data=valid_ds,
                epochs=epochs,
                callbacks=callbacks)

# %%
print("Evaluate model on valid data")
results1 = m.evaluate(valid_ds)
print("Evaluate pruned model on valid data")
results2 = pruned_model.evaluate(valid_ds)

# %%
pruned_model.save('E:\EE\project\FPGA\pruned_model_SparsityDecay.tf')

# %%
def print_model_weights_sparsity(model):

    for layer in model.layers:
        if isinstance(layer, tf.keras.layers.Wrapper):
            weights = layer.trainable_weights
        else:
            weights = layer.weights
        for weight in weights:
            if "kernel" not in weight.name or "centroid" in weight.name:
                continue
            weight_size = weight.numpy().size
            zero_num = np.count_nonzero(weight == 0)
            print(
                f"{weight.name}: {zero_num/weight_size:.2%} sparsity ",
                f"({zero_num}/{weight_size})",
            )

# %%
stripped_pruned_model = tfmot.sparsity.keras.strip_pruning(pruned_model)

print_model_weights_sparsity(stripped_pruned_model)

stripped_pruned_model_copy = tf.keras.models.clone_model(stripped_pruned_model)
stripped_pruned_model_copy.set_weights(stripped_pruned_model.get_weights())

# %%
# Test Image
src = cv2.imread('E:/EE/project/FPGA/test_01.png')
start = time.time()
result = img_pred(src,stripped_pruned_model)[2]
end = time.time()
fps = 1/(end-start)
print('fps =',fps)
cv2.imshow("result",result)
cv2.waitKey (0)

# %%
stripped_pruned_model.save('E:\EE\project\FPGA\stripped_pruned_model_SparsityDecay.tf', include_optimizer=False)

# %%
stripped_pruned_model_copy = tf.keras.models.load_model('E:\EE\project\FPGA\stripped_pruned_model_SparsityDecay.tf',custom_objects={'ArgmaxMeanIOU': ArgmaxMeanIOU})
opt = tf.keras.optimizers.Adam(learning_rate=5e-6)
stripped_pruned_model_copy.compile(opt, loss=cce,
                  metrics=['accuracy', ArgmaxMeanIOU(NUM_CLASSES)])

# %%
import tensorflow_model_optimization as tfmot

# Clustering
cluster_weights = tfmot.clustering.keras.cluster_weights
CentroidInitialization = tfmot.clustering.keras.CentroidInitialization

#clustering_params = {
#  'number_of_clusters': 8,
#  'cluster_centroids_init': CentroidInitialization.KMEANS_PLUS_PLUS
#}

#clustered_model = cluster_weights(stripped_pruned_model, **clustering_params)

#clustered_model.compile(sgd, loss=cce,
 #                 metrics=['accuracy', ArgmaxMeanIOU(NUM_CLASSES)]) 

#print('Train clustering model:')
#clustered_model.fit(train_ds, validation_data=valid_dsvalid_ds, epochs=5)


#stripped_pruned_model.save("/content/drive/MyDrive/Colab_Notebooks/stripped_pruned_model_clustered.tf")


# Sparsity preserving clustering
from tensorflow_model_optimization.python.core.clustering.keras.experimental import (
    cluster,
)

cluster_weights = cluster.cluster_weights

clustering_params = {
  'number_of_clusters': 8,
  'cluster_centroids_init': CentroidInitialization.KMEANS_PLUS_PLUS,
  'preserve_sparsity': True
}

sparsity_clustered_model = cluster_weights(stripped_pruned_model_copy, **clustering_params)
opt = tf.keras.optimizers.Adam(learning_rate=5e-6)
sparsity_clustered_model.compile(opt, loss=cce,
                  metrics=['accuracy', ArgmaxMeanIOU(NUM_CLASSES)])

print('Train sparsity preserving clustering model:')
sparsity_clustered_model.fit(train_ds, validation_data=valid_ds, epochs=5)
sparsity_clustered_model.save("E:\EE\project\FPGA\sparsity_clustered_model.tf")

# %%
stripped_sparsity_clustered_model = tfmot.clustering.keras.strip_clustering(sparsity_clustered_model)
stripped_sparsity_clustered_model.save("E:\EE\project\FPGA\stripped_sparsity_clustered_model.tf",include_optimizer=False)

# %%
import tensorflow_model_optimization as tfmot


stripped_sparsity_clustered_model = tf.keras.models.load_model("E:\EE\project\FPGA\stripped_sparsity_clustered_model.tf")
prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude

epochs = 1
end_step = np.ceil(len(train_ds)).astype(np.int32)*epochs
pruning_params = {
      'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.5,
                                    final_sparsity=0.80,
                                    begin_step=0,
                                    end_step=end_step)}
#pruning_params = {
#      'pruning_schedule': tfmot.sparsity.keras.ConstantSparsity(0.5, begin_step=0, frequency=100)
#  }
opt = tf.keras.optimizers.Adam(learning_rate=5e-6)
pruned_model = prune_low_magnitude(stripped_sparsity_clustered_model, **pruning_params)

pruned_model.compile(opt, loss=cce,
                  metrics=['accuracy', ArgmaxMeanIOU(NUM_CLASSES)]) 
pruned_model.summary()
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# C:\Users\andre\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:2191: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 512, 3) 0
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d (Pru (None, 128, 256, 16) 882         input_1[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 128, 256, 16) 65          prune_low_magnitude_conv2d[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_activation  (None, 128, 256, 16) 1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_1 (P (None, 128, 256, 8)  266         prune_low_magnitude_activation[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 128, 256, 8)  33          prune_low_magnitude_conv2d_1[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 128, 256, 8)  1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_2 (P (None, 64, 128, 16)  2322        prune_low_magnitude_activation_1[
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 64, 128, 16)  65          prune_low_magnitude_conv2d_2[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 64, 128, 16)  1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_max_pooling (None, 64, 128, 16)  1           prune_low_magnitude_activation[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_concatenate (None, 64, 128, 32)  1           prune_low_magnitude_activation_2[
#                                                                  prune_low_magnitude_max_pooling2d
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_3 (P (None, 64, 128, 16)  9234        prune_low_magnitude_concatenate[0
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 64, 128, 16)  65          prune_low_magnitude_conv2d_3[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 64, 128, 16)  1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_4 (P (None, 64, 128, 32)  9250        prune_low_magnitude_activation_3[
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 64, 128, 32)  129         prune_low_magnitude_conv2d_4[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 64, 128, 32)  1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 32, 64, 192)  1921        prune_low_magnitude_activation_4[
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 32, 64, 192)  769         prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 32, 64, 1152) 11521       prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 32, 64, 96)   961         prune_low_magnitude_activation_3[
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 32, 64, 1152) 4609        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 32, 64, 96)   385         prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_6 (P (None, 32, 64, 32)   73762       prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_5 (P (None, 32, 64, 32)   6178        prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 32, 64, 32)   129         prune_low_magnitude_conv2d_6[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 32, 64, 32)   129         prune_low_magnitude_conv2d_5[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_add (PruneL (None, 32, 64, 32)   1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 32, 64, 32)   1           prune_low_magnitude_add[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_7 (P (None, 32, 64, 32)   18466       prune_low_magnitude_activation_5[
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 32, 64, 32)   129         prune_low_magnitude_conv2d_7[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 32, 64, 32)   1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 32, 64, 192)  1921        prune_low_magnitude_activation_6[
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 32, 64, 192)  769         prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_8 (P (None, 32, 64, 32)   12322       prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 32, 64, 32)   129         prune_low_magnitude_conv2d_8[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_add_1 (Prun (None, 32, 64, 32)   1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_activation_5[
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 32, 64, 32)   1           prune_low_magnitude_add_1[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_9 (P (None, 32, 64, 64)   36930       prune_low_magnitude_activation_7[
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 32, 64, 64)   257         prune_low_magnitude_conv2d_9[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 32, 64, 64)   1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 16, 32, 384)  3841        prune_low_magnitude_activation_8[
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 16, 32, 384)  1537        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 16, 32, 2304) 23041       prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 16, 32, 192)  1921        prune_low_magnitude_activation_7[
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 16, 32, 2304) 9217        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 16, 32, 192)  769         prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_11 ( (None, 16, 32, 64)   294978      prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_10 ( (None, 16, 32, 64)   24642       prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 16, 32, 64)   257         prune_low_magnitude_conv2d_11[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 16, 32, 64)   257         prune_low_magnitude_conv2d_10[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_add_2 (Prun (None, 16, 32, 64)   1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 16, 32, 64)   1           prune_low_magnitude_add_2[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_12 ( (None, 16, 32, 64)   73794       prune_low_magnitude_activation_9[
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 16, 32, 64)   257         prune_low_magnitude_conv2d_12[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 16, 32, 64)   1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 16, 32, 384)  3841        prune_low_magnitude_activation_10
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 16, 32, 384)  1537        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_13 ( (None, 16, 32, 64)   49218       prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 16, 32, 64)   257         prune_low_magnitude_conv2d_13[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_add_3 (Prun (None, 16, 32, 64)   1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_activation_9[
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 16, 32, 64)   1           prune_low_magnitude_add_3[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_14 ( (None, 16, 32, 128)  147586      prune_low_magnitude_activation_11
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 16, 32, 128)  513         prune_low_magnitude_conv2d_14[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 16, 32, 128)  1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 8, 16, 768)   7681        prune_low_magnitude_activation_12
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 16, 768)   3073        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 8, 16, 4608)  46081       prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 8, 16, 384)   3841        prune_low_magnitude_activation_11
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 16, 4608)  18433       prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 16, 384)   1537        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_16 ( (None, 8, 16, 128)   1179778     prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_15 ( (None, 8, 16, 128)   98434       prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 16, 128)   513         prune_low_magnitude_conv2d_16[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 16, 128)   513         prune_low_magnitude_conv2d_15[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_add_4 (Prun (None, 8, 16, 128)   1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 8, 16, 128)   1           prune_low_magnitude_add_4[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_17 ( (None, 8, 16, 128)   295042      prune_low_magnitude_activation_13
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 16, 128)   513         prune_low_magnitude_conv2d_17[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 8, 16, 128)   1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 8, 16, 768)   7681        prune_low_magnitude_activation_14
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 16, 768)   3073        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_18 ( (None, 8, 16, 128)   196738      prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 16, 128)   513         prune_low_magnitude_conv2d_18[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_add_5 (Prun (None, 8, 16, 128)   1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_activation_13
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 8, 16, 128)   1           prune_low_magnitude_add_5[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_19 ( (None, 8, 16, 128)   295042      prune_low_magnitude_activation_15
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 16, 128)   513         prune_low_magnitude_conv2d_19[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 8, 16, 128)   1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_25 ( (None, 128, 256, 64) 3522        input_1[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 8, 16, 768)   7681        prune_low_magnitude_activation_16
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 128, 256, 64) 257         prune_low_magnitude_conv2d_25[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 16, 768)   3073        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 128, 256, 64) 1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_20 ( (None, 8, 16, 128)   196738      prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_26 ( (None, 128, 256, 64) 73794       prune_low_magnitude_activation_21
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 16, 128)   513         prune_low_magnitude_conv2d_20[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 128, 256, 64) 257         prune_low_magnitude_conv2d_26[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_add_6 (Prun (None, 8, 16, 128)   1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_activation_15
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 128, 256, 64) 1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 8, 16, 128)   1           prune_low_magnitude_add_6[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_27 ( (None, 64, 128, 64)  73794       prune_low_magnitude_activation_22
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_21 ( (None, 8, 16, 128)   295042      prune_low_magnitude_activation_17
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 64, 128, 64)  257         prune_low_magnitude_conv2d_27[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 16, 128)   513         prune_low_magnitude_conv2d_21[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 64, 128, 64)  1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 8, 16, 128)   1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_28 ( (None, 64, 128, 64)  73794       prune_low_magnitude_activation_23
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 8, 16, 768)   7681        prune_low_magnitude_activation_18
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 64, 128, 64)  257         prune_low_magnitude_conv2d_28[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 16, 768)   3073        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 64, 128, 64)  1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_22 ( (None, 8, 16, 128)   196738      prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_29 ( (None, 64, 128, 64)  73794       prune_low_magnitude_activation_24
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 16, 128)   513         prune_low_magnitude_conv2d_22[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 64, 128, 64)  257         prune_low_magnitude_conv2d_29[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_add_7 (Prun (None, 8, 16, 128)   1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_activation_17
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 64, 128, 64)  1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 8, 16, 128)   1           prune_low_magnitude_add_7[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_30 ( (None, 32, 64, 128)  147586      prune_low_magnitude_activation_25
# __________________________________________________________________________________________________
# prune_low_magnitude_global_aver (None, 128)          1           prune_low_magnitude_activation_19
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 32, 64, 128)  513         prune_low_magnitude_conv2d_30[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 128)          513         prune_low_magnitude_global_averag
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 32, 64, 128)  1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_reshape (Pr (None, 1, 1, 128)    1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_31 ( (None, 32, 64, 128)  295042      prune_low_magnitude_activation_26
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_23 ( (None, 1, 1, 128)    32898       prune_low_magnitude_reshape[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 32, 64, 128)  513         prune_low_magnitude_conv2d_31[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 1, 1, 128)    513         prune_low_magnitude_conv2d_23[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 32, 64, 128)  1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 1, 1, 128)    1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_32 ( (None, 32, 64, 128)  295042      prune_low_magnitude_activation_27
# __________________________________________________________________________________________________
# prune_low_magnitude_add_8 (Prun (None, 8, 16, 128)   1           prune_low_magnitude_activation_20
#                                                                  prune_low_magnitude_activation_19
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 32, 64, 128)  513         prune_low_magnitude_conv2d_32[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_24 ( (None, 8, 16, 128)   295042      prune_low_magnitude_add_8[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 32, 64, 128)  1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 8, 16, 128)   1281        prune_low_magnitude_conv2d_24[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_36 ( (None, 8, 16, 128)   295042      prune_low_magnitude_conv2d_24[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 16, 128)   513         prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_34 ( (None, 16, 32, 128)  295042      prune_low_magnitude_activation_28
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 32, 64, 128)  1281        prune_low_magnitude_activation_28
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 16, 128)   513         prune_low_magnitude_conv2d_36[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_35 ( (None, 8, 16, 128)   32898       prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 16, 32, 128)  513         prune_low_magnitude_conv2d_34[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 32, 64, 128)  513         prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_up_sampling (None, 32, 64, 128)  1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 8, 16, 128)   1           prune_low_magnitude_conv2d_35[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_average_poo (None, 8, 16, 128)   1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_33 ( (None, 32, 64, 128)  32898       prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 32, 64, 128)  1           prune_low_magnitude_up_sampling2d
# __________________________________________________________________________________________________
# prune_low_magnitude_multiply_1  (None, 8, 16, 128)   1           prune_low_magnitude_activation_29
#                                                                  prune_low_magnitude_average_pooli
# __________________________________________________________________________________________________
# prune_low_magnitude_multiply (P (None, 32, 64, 128)  1           prune_low_magnitude_conv2d_33[0][
#                                                                  prune_low_magnitude_activation_30
# __________________________________________________________________________________________________
# prune_low_magnitude_up_sampling (None, 32, 64, 128)  1           prune_low_magnitude_multiply_1[0]
# __________________________________________________________________________________________________
# prune_low_magnitude_add_9 (Prun (None, 32, 64, 128)  1           prune_low_magnitude_multiply[0][0
#                                                                  prune_low_magnitude_up_sampling2d
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_37 ( (None, 32, 64, 128)  295042      prune_low_magnitude_add_9[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 32, 64, 128)  513         prune_low_magnitude_conv2d_37[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_38 ( (None, 32, 64, 4)    9222        prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 32, 64, 4)    17          prune_low_magnitude_conv2d_38[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_activation_ (None, 32, 64, 4)    1           prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_39 ( (None, 32, 64, 2)    148         prune_low_magnitude_activation_31
# __________________________________________________________________________________________________
# prune_low_magnitude_up_sampling (None, 256, 512, 2)  1           prune_low_magnitude_conv2d_39[0][
# ==================================================================================================
# Total params: 6,035,271
# Trainable params: 3,085,262
# Non-trainable params: 2,950,009
# __________________________________________________________________________________________________

# %%
import tempfile
logdir = tempfile.mkdtemp()
callbacks = [
  tfmot.sparsity.keras.UpdatePruningStep()
]   
history = pruned_model.fit(train_ds,
                validation_data=valid_ds,
                epochs=epochs,
                callbacks=callbacks)
# Out:
# WARNING:tensorflow:From C:\Users\andre\anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# WARNING:tensorflow:From C:\Users\andre\anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# 186/186 [==============================] - 361s 2s/step - loss: 0.1028 - accuracy: 0.9595 - argmax_mean_iou: 0.9121 - val_loss: 0.1260 - val_accuracy: 0.9499 - val_argmax_mean_iou: 0.8934

# %%
stripped_pruned_model = tfmot.sparsity.keras.strip_pruning(pruned_model)

# %%
stripped_pruned_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 512, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 256, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 256, 16) 64          conv2d[2][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 128, 256, 16) 0           batch_normalization[2][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 256, 8)  136         activation[2][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 256, 8)  32          conv2d_1[2][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 256, 8)  0           batch_normalization_1[2][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 128, 16)  1168        activation_1[2][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 128, 16)  64          conv2d_2[2][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 128, 16)  0           batch_normalization_2[2][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 128, 16)  0           activation[2][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 128, 32)  0           activation_2[2][0]
#                                                                  max_pooling2d[2][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 128, 16)  4624        concatenate[2][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 128, 16)  64          conv2d_3[2][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 128, 16)  0           batch_normalization_3[2][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 128, 32)  4640        activation_3[2][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 128, 32)  128         conv2d_4[2][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 128, 32)  0           batch_normalization_4[2][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 32, 64, 192)  1920        activation_4[2][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 64, 192)  768         depthwise_conv2d[2][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 32, 64, 1152) 11520       batch_normalization_5[2][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 32, 64, 96)   960         activation_3[2][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 64, 1152) 4608        depthwise_conv2d_2[2][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 64, 96)   384         depthwise_conv2d_1[2][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 64, 32)   36896       batch_normalization_8[2][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 64, 32)   3104        batch_normalization_6[2][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 64, 32)   128         conv2d_6[2][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 64, 32)   128         conv2d_5[2][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 64, 32)   0           batch_normalization_9[2][0]
#                                                                  batch_normalization_7[2][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 64, 32)   0           add[2][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 64, 32)   9248        activation_5[2][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 64, 32)   128         conv2d_7[2][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 64, 32)   0           batch_normalization_10[2][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 32, 64, 192)  1920        activation_6[2][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 64, 192)  768         depthwise_conv2d_3[2][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 64, 32)   6176        batch_normalization_11[2][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 64, 32)   128         conv2d_8[2][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 64, 32)   0           batch_normalization_12[2][0]
#                                                                  activation_5[2][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 64, 32)   0           add_1[2][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 64, 64)   18496       activation_7[2][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 64, 64)   256         conv2d_9[2][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 64, 64)   0           batch_normalization_13[2][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 16, 32, 384)  3840        activation_8[2][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 32, 384)  1536        depthwise_conv2d_4[2][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 16, 32, 2304) 23040       batch_normalization_14[2][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 16, 32, 192)  1920        activation_7[2][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 32, 2304) 9216        depthwise_conv2d_6[2][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 32, 192)  768         depthwise_conv2d_5[2][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 32, 64)   147520      batch_normalization_17[2][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 32, 64)   12352       batch_normalization_15[2][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 32, 64)   256         conv2d_11[2][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 32, 64)   256         conv2d_10[2][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 32, 64)   0           batch_normalization_18[2][0]
#                                                                  batch_normalization_16[2][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 32, 64)   0           add_2[2][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 32, 64)   36928       activation_9[2][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 32, 64)   256         conv2d_12[2][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 32, 64)   0           batch_normalization_19[2][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 16, 32, 384)  3840        activation_10[2][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 32, 384)  1536        depthwise_conv2d_7[2][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 32, 64)   24640       batch_normalization_20[2][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 16, 32, 64)   256         conv2d_13[2][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 32, 64)   0           batch_normalization_21[2][0]
#                                                                  activation_9[2][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 32, 64)   0           add_3[2][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 32, 128)  73856       activation_11[2][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 16, 32, 128)  512         conv2d_14[2][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 32, 128)  0           batch_normalization_22[2][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 8, 16, 768)   7680        activation_12[2][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 8, 16, 768)   3072        depthwise_conv2d_8[2][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 8, 16, 4608)  46080       batch_normalization_23[2][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 8, 16, 384)   3840        activation_11[2][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 16, 4608)  18432       depthwise_conv2d_10[2][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 16, 384)   1536        depthwise_conv2d_9[2][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 16, 128)   589952      batch_normalization_26[2][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 16, 128)   49280       batch_normalization_24[2][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 16, 128)   512         conv2d_16[2][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 16, 128)   512         conv2d_15[2][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 16, 128)   0           batch_normalization_27[2][0]
#                                                                  batch_normalization_25[2][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 16, 128)   0           add_4[2][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 16, 128)   147584      activation_13[2][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 16, 128)   512         conv2d_17[2][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 16, 128)   0           batch_normalization_28[2][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 8, 16, 768)   7680        activation_14[2][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 16, 768)   3072        depthwise_conv2d_11[2][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 16, 128)   98432       batch_normalization_29[2][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 8, 16, 128)   512         conv2d_18[2][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 16, 128)   0           batch_normalization_30[2][0]
#                                                                  activation_13[2][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 8, 16, 128)   0           add_5[2][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 16, 128)   147584      activation_15[2][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 8, 16, 128)   512         conv2d_19[2][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 16, 128)   0           batch_normalization_31[2][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 128, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 8, 16, 768)   7680        activation_16[2][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 128, 256, 64) 256         conv2d_25[2][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 8, 16, 768)   3072        depthwise_conv2d_12[2][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 128, 256, 64) 0           batch_normalization_39[2][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 16, 128)   98432       batch_normalization_32[2][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 128, 256, 64) 36928       activation_21[2][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 8, 16, 128)   512         conv2d_20[2][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 128, 256, 64) 256         conv2d_26[2][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 16, 128)   0           batch_normalization_33[2][0]
#                                                                  activation_15[2][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 128, 256, 64) 0           batch_normalization_40[2][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 16, 128)   0           add_6[2][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 128, 64)  36928       activation_22[2][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 16, 128)   147584      activation_17[2][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 64, 128, 64)  256         conv2d_27[2][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 16, 128)   512         conv2d_21[2][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 64, 128, 64)  0           batch_normalization_41[2][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 16, 128)   0           batch_normalization_34[2][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 128, 64)  36928       activation_23[2][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 8, 16, 768)   7680        activation_18[2][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 64, 128, 64)  256         conv2d_28[2][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 8, 16, 768)   3072        depthwise_conv2d_13[2][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 64, 128, 64)  0           batch_normalization_42[2][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 16, 128)   98432       batch_normalization_35[2][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 128, 64)  36928       activation_24[2][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 8, 16, 128)   512         conv2d_22[2][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 64, 128, 64)  256         conv2d_29[2][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 16, 128)   0           batch_normalization_36[2][0]
#                                                                  activation_17[2][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 64, 128, 64)  0           batch_normalization_43[2][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 16, 128)   0           add_7[2][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 64, 128)  73856       activation_25[2][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 128)          0           activation_19[2][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 32, 64, 128)  512         conv2d_30[2][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 128)          512         global_average_pooling2d[2][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 32, 64, 128)  0           batch_normalization_44[2][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 128)    0           batch_normalization_37[2][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 64, 128)  147584      activation_26[2][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 1, 1, 128)    16512       reshape[2][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 32, 64, 128)  512         conv2d_31[2][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 1, 1, 128)    512         conv2d_23[2][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 32, 64, 128)  0           batch_normalization_45[2][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 1, 1, 128)    0           batch_normalization_38[2][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 64, 128)  147584      activation_27[2][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 8, 16, 128)   0           activation_20[2][0]
#                                                                  activation_19[2][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 32, 64, 128)  512         conv2d_32[2][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 8, 16, 128)   147584      add_8[2][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 64, 128)  0           batch_normalization_46[2][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 8, 16, 128)   1280        conv2d_24[2][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 16, 128)   147584      conv2d_24[2][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 8, 16, 128)   512         depthwise_conv2d_15[2][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 32, 128)  147584      activation_28[2][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 32, 64, 128)  1280        activation_28[2][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 8, 16, 128)   512         conv2d_36[2][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 16, 128)   16512       batch_normalization_49[2][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 16, 32, 128)  512         conv2d_34[2][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 32, 64, 128)  512         depthwise_conv2d_14[2][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 64, 128)  0           batch_normalization_50[2][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 8, 16, 128)   0           conv2d_35[2][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 8, 16, 128)   0           batch_normalization_48[2][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 64, 128)  16512       batch_normalization_47[2][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 32, 64, 128)  0           up_sampling2d[2][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 8, 16, 128)   0           activation_29[2][0]
#                                                                  average_pooling2d[2][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 32, 64, 128)  0           conv2d_33[2][0]
#                                                                  activation_30[2][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 64, 128)  0           multiply_1[2][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 32, 64, 128)  0           multiply[2][0]
#                                                                  up_sampling2d_1[2][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 32, 64, 128)  147584      add_9[2][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 32, 64, 128)  512         conv2d_37[2][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 32, 64, 4)    4612        batch_normalization_51[2][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 32, 64, 4)    16          conv2d_38[2][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 32, 64, 4)    0           batch_normalization_52[2][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 32, 64, 2)    74          activation_31[2][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 256, 512, 2)  0           conv2d_39[2][0]
# ==================================================================================================
# Total params: 3,117,766
# Trainable params: 3,085,262
# Non-trainable params: 32,504
# __________________________________________________________________________________________________

# %%
# Test Image
src = cv2.imread('E:/EE/project/FPGA/test_01.png')
start = time.time()
result = img_pred(src,stripped_pruned_model)[2]
end = time.time()
fps = 1/(end-start)
print('fps =',fps)
cv2.imshow("result",result)
cv2.waitKey (0)
# Out:
# fps = 17.00515307177406
# -1

# %%
# Quantize model to a tflite int8 model (exclude I/O) speed up for ARM

model = tf.keras.models.load_model('model.tf',custom_objects={'ArgmaxMeanIOU': ArgmaxMeanIOU})
cityscapes = tfds.load('cityscapes/semantic_segmentation',data_dir="drive/MyDrive/Colab_Notebooks/dataset",download=False)
test_ds = cityscapes['test'].map(cityscapes_prep(OUTPUT_SHAPE, INPUT_SHAPE, class_map_road))

def representative_dataset():
  for data in test_ds.take(50).batch(1):
      yield [data[0]]

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
#converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
#converter.inference_input_type = tf.uint8
#converter.inference_output_type = tf.uint8
tflite_quant_model_IOfloat32 = converter.convert()

# %%
# Check input/output dtype
interpreter = tf.lite.Interpreter(model_content=tflite_quant_model_IOfloat32)
input_type = interpreter.get_input_details()[0]['dtype']
print('input: ', input_type)
output_type = interpreter.get_output_details()[0]['dtype']
print('output: ', output_type)

# %%
# Quantize model to a tflite int8 model speed up for ARM

model = tf.keras.models.load_model('model.tf',custom_objects={'ArgmaxMeanIOU': ArgmaxMeanIOU})
cityscapes = tfds.load('cityscapes/semantic_segmentation',data_dir="drive/MyDrive/Colab_Notebooks/dataset",download=False)
test_ds = cityscapes['test'].map(cityscapes_prep(OUTPUT_SHAPE, INPUT_SHAPE, class_map_road))

def representative_dataset():
  for data in test_ds.take(50).batch(1):
      yield [data[0]]

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.uint8
converter.inference_output_type = tf.uint8
tflite_quant_model_fullyINT8 = converter.convert()

# %%
# Check input/output dtype
interpreter = tf.lite.Interpreter(model_content=tflite_quant_model_fullyINT8)
input_type = interpreter.get_input_details()[0]['dtype']
print('input: ', input_type)
output_type = interpreter.get_output_details()[0]['dtype']
print('output: ', output_type)

# %%
# Save float and int tflite model
import pathlib

tflite_models_dir = pathlib.Path("/content/drive/MyDrive/Colab_Notebooks/FPGA_RoadSeg/cityscapes_tflite_models/")
tflite_models_dir.mkdir(exist_ok=True, parents=True)

tflite_model_quant_iofloat_file = tflite_models_dir/"cityscapes_iofloat32.tflite"
tflite_model_quant_iofloat_file.write_bytes(tflite_quant_model_IOfloat32)

tflite_model_quant_fullINT_file = tflite_models_dir/"cityscapes_fullyINT8.tflite"
tflite_model_quant_fullINT_file.write_bytes(tflite_quant_model_fullyINT8)

# %%
# Helper function to run inference on a TFLite model with image
def run_tflite_model(tflite_file, test_image):

  # Initialize the interpreter
  interpreter = tf.lite.Interpreter(model_path=str(tflite_file))
  interpreter.allocate_tensors()

  input_details = interpreter.get_input_details()[0]
  output_details = interpreter.get_output_details()[0]

  test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)
  test_image = cv2.resize(test_image,(512,256),interpolation=cv2.INTER_CUBIC)
  image = test_image/255
  data = tf.convert_to_tensor(image, dtype=tf.uint8)
  data = tf.expand_dims(data, axis=0)
  interpreter.set_tensor(input_details["index"], data)

  start = time.time()
  interpreter.invoke()
  end = time.time()

  print(f'invoke: {e-s:.3f}s ({1/(e-s):.2f} fps)')

  output = interpreter.get_tensor(output_details["index"])[0]

  seg = tf.argmax(pred[0], axis=-1)
  seg = seg[..., tf.newaxis]
  seg = tf.keras.preprocessing.image.array_to_img(seg)
  #plt.imshow(seg)
  seg = cv2.cvtColor(np.array(seg), cv2.COLOR_BGR2RGB)
  result = cv2.addWeighted(src, 0.6, seg, 0.5, 0, dtype = cv2.CV_8U)

  return src, seg, result

# %%
src = cv2.imread('/content/drive/MyDrive/Colab_Notebooks/FPGA_RoadSeg/test_02.png')

result = run_tflite_model(tflite_model_quant_fullINT_file,src)[2]

cv2_imshow(result)

# %%
# helper function to evaluate on the tf dataset
import time 
interpreter = tf.lite.Interpreter(model_path=str(tflite_model_quant_fullINT_file))
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()[0]
output_details = interpreter.get_output_details()[0]
def pred_func(sample):
    input_data = tf.expand_dims(sample[0], axis=0)
    input_data = tf.cast(input_data, tf.dtypes.uint8)
    
    #truth_data = sample[1]
    
    interpreter.set_tensor(input_details[0]['index'], input_data)
    
    s = time.time()
    interpreter.invoke()
    e = time.time()
    print(f'invoke: {e-s:.3f}s ({1/(e-s):.2f} fps)')
    output_data = interpreter.get_tensor(output_details[0]['index'])
    
    return input_data[0], output_data[0]

display_dataset(test_ds.take(10), pred_func)
